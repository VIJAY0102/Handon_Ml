# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Acquisition

# %%
data = pd.read_csv('DataSet/mushrooms.csv')
data.head()
# Out:
#   class cap_shape cap_surface cap_color bruises odor gill_attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill_spacing gill_size gill_color   ...   stalk_surface_below_ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
#
#   stalk_color_above_ring stalk_color_below_ring veil_type veil_color  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

dataNumeric = data.copy()

for col in dataNumeric.columns.values:
    dataNumeric[col] = LabelEncoder().fit_transform(dataNumeric[col])

dataNumeric.head()
# Out:
#    class  cap_shape  cap_surface  cap_color  bruises  odor  gill_attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill_spacing  gill_size  gill_color   ...     stalk_surface_below_ring  \
# 0             0          1           4   ...                            2
# 1             0          0           4   ...                            2
# 2             0          0           5   ...                            2
# 3             0          1           5   ...                            2
# 4             1          0           4   ...                            2
#
# ...

# %% [markdown]
# # Data Processing

# %% [markdown]
# ### Data Cleaning

# %%
dataNumeric = dataNumeric.drop(['veil_type'], axis=1)

# %%
dataNumeric.corr()
# Out:
#                              class  cap_shape  cap_surface  cap_color  \
# class                     1.000000   0.052951     0.178446  -0.031384
# cap_shape                 0.052951   1.000000    -0.050454  -0.048203
# cap_surface               0.178446  -0.050454     1.000000  -0.019402
# cap_color                -0.031384  -0.048203    -0.019402   1.000000
# bruises                  -0.501530  -0.035374     0.070228  -0.000764
# odor                     -0.093552  -0.021935     0.045233  -0.387121
# gill_attachment           0.129200   0.078865    -0.034180   0.041436
# gill_spacing             -0.348387   0.013196    -0.282306   0.144259
# gill_size                 0.540024   0.054050     0.208100  -0.169464
# gill_color               -0.530566  -0.006039    -0.161017   0.084659
# stalk_shape              -0.102019   0.063794    -0.014123  -0.456496
# stalk_root               -0.379361   0.030191    -0.126245   0.321274
# ...

# %%
plt.rcParams["figure.figsize"] = (20, 20)
plt.matshow(dataNumeric.corr())
plt.xticks(range(0, 23), dataNumeric.columns, rotation='vertical')
plt.show()

# %% [markdown]
# # Data Analysing

# %% [markdown]
# ## K Nearest Neighbour

# %%
label = dataNumeric.values[:, :1]
feature = dataNumeric.values[:, 1:]

# %%
from sklearn import model_selection

# %%
labels, testLabels, features, testFeatures = model_selection.train_test_split(label, feature, test_size=0.2, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier
training = KNeighborsClassifier()
training = training.fit(features, labels.ravel())

# %%
predict = training.predict(testFeatures)
predict
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(accuracy_score(testLabels, predict))
print(confusion_matrix(testLabels, predict))
print(classification_report(testLabels, predict))
# Out:
# 0.996307692308
# [[837   6]
#  [  0 782]]
#              precision    recall  f1-score   support
#
#           0       1.00      0.99      1.00       843
#           1       0.99      1.00      1.00       782
#
# avg / total       1.00      1.00      1.00      1625

# %% [markdown]
# ## Decision Tree

# %%
from sklearn import tree

# %%
training1 = tree.DecisionTreeClassifier()
training1 = training1.fit(features, labels)

# %%
predict = training1.predict(testFeatures)
predict
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
print(accuracy_score(testLabels, predict))
print(confusion_matrix(testLabels, predict))
print(classification_report(testLabels, predict))
# Out:
# 1.0
# [[843   0]
#  [  0 782]]
#              precision    recall  f1-score   support
#
#           0       1.00      1.00      1.00       843
#           1       1.00      1.00      1.00       782
#
# avg / total       1.00      1.00      1.00      1625

# %% [markdown]
# # Reporting

# %%
attribute_values = {'cap_shape': 'bcxfks', 
                    'cap_surface': 'fgys', 
                    'cap_color': 'nbcgrpuewy', 
                    'bruises': 'tf', 
                    'odor': 'alcyfmnps', 
                    'gill_attachment': 'adfn', 
                    'gill_spacing': 'cwd', 
                    'gill_size': 'bn', 
                    'gill_color': 'knbhgropuewy',
                    'stalk_shape': 'et',
                    'stalk_root': 'bcuezr?',
                    'stalk_surface_above_ring': 'fyks',
                    'stalk_surface_below_ring': 'fyks',
                    'stalk_color_above_ring': 'nbcgopewy',
                    'stalk_color_below_ring': 'nbcgopewy',
                    'veil_type': 'pu',
                    'veil_color': 'nowy',
                    'ring_number': 'not',
                    'ring_type': 'ceflnpsz',
                    'spore_print_color': 'knbhrouwy',
                    'population': 'acnsvy',
                    'habitat': 'glmpuwd'}

# %%
#bind_data = {}
bind_data = []
for iter1 in attribute_values:
    column = {}
    for iter2 in range(len(attribute_values[iter1])):
        column[attribute_values[iter1][iter2]] = iter2
    #bind_data.update({iter1: column})
    bind_data.append(column)
bind_data
# Out:
# [{'b': 0, 'c': 1, 'f': 3, 'k': 4, 's': 5, 'x': 2},
#  {'f': 0, 'g': 1, 's': 3, 'y': 2},
#  {'b': 1,
#   'c': 2,
#   'e': 7,
#   'g': 3,
#   'n': 0,
#   'p': 5,
#   'r': 4,
#   'u': 6,
#   'w': 8,
#   'y': 9},
#  {'f': 1, 't': 0},
#  {'a': 0, 'c': 2, 'f': 4, 'l': 1, 'm': 5, 'n': 6, 'p': 7, 's': 8, 'y': 3},
#  {'a': 0, 'd': 1, 'f': 2, 'n': 3},
#  {'c': 0, 'd': 2, 'w': 1},
#  {'b': 0, 'n': 1},
#  {'b': 2,
#   'e': 9,
#   'g': 4,
#   'h': 3,
#   'k': 0,
#   'n': 1,
#   'o': 6,
#   'p': 7,
#   'r': 5,
#   'u': 8,
#   'w': 10,
#   'y': 11},
#  {'e': 0, 't': 1},
#  {'?': 6, 'b': 0, 'c': 1, 'e': 3, 'r': 5, 'u': 2, 'z': 4},
#  {'f': 0, 'k': 2, 's': 3, 'y': 1},
#  {'f': 0, 'k': 2, 's': 3, 'y': 1},
#  {'b': 1, 'c': 2, 'e': 6, 'g': 3, 'n': 0, 'o': 4, 'p': 5, 'w': 7, 'y': 8},
#  {'b': 1, 'c': 2, 'e': 6, 'g': 3, 'n': 0, 'o': 4, 'p': 5, 'w': 7, 'y': 8},
#  {'p': 0, 'u': 1},
#  {'n': 0, 'o': 1, 'w': 2, 'y': 3},
#  {'n': 0, 'o': 1, 't': 2},
# ...

# %% [markdown]
# Attribute Information: (classes: edible=e, poisonous=p)
#
# - cap-shape: bell=b,conical=c,convex=x,flat=f, knobbed=k,sunken=s
#
# - cap-surface: fibrous=f,grooves=g,scaly=y,smooth=s
#
# - cap-color: brown=n,buff=b,cinnamon=c,gray=g,green=r,pink=p,purple=u,red=e,white=w,yellow=y
#
# - bruises: bruises=t,no=f
#
# - odor: almond=a,anise=l,creosote=c,fishy=y,foul=f,musty=m,none=n,pungent=p,spicy=s
#
# - gill-attachment: attached=a,descending=d,free=f,notched=n
#
# - gill-spacing: close=c,crowded=w,distant=d
#
# - gill-size: broad=b,narrow=n
#
# - gill-color: black=k,brown=n,buff=b,chocolate=h,gray=g, green=r,orange=o,pink=p,purple=u,red=e,white=w,yellow=y
#
# - stalk-shape: enlarging=e,tapering=t
#
# - stalk-root: bulbous=b,club=c,cup=u,equal=e,rhizomorphs=z,rooted=r,missing=?
#
# - stalk-surface-above-ring: fibrous=f,scaly=y,silky=k,smooth=s
#
# - stalk-surface-below-ring: fibrous=f,scaly=y,silky=k,smooth=s
#
# - stalk-color-above-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
#
# - stalk-color-below-ring: brown=n,buff=b,cinnamon=c,gray=g,orange=o,pink=p,red=e,white=w,yellow=y
#
# - veil-type: partial=p,universal=u
#
# - veil-color: brown=n,orange=o,white=w,yellow=y
#
# - ring-number: none=n,one=o,two=t
#
# - ring-type: cobwebby=c,evanescent=e,flaring=f,large=l,none=n,pendant=p,sheathing=s,zone=z
#
# - spore-print-color: black=k,brown=n,buff=b,chocolate=h,green=r,orange=o,purple=u,white=w,yellow=y
#
# - population: abundant=a,clustered=c,numerous=n,scattered=s,several=v,solitary=y
#
# - habitat: grasses=g,leaves=l,meadows=m,paths=p,urban=u,waste=w,woods=d

# %%
if(training1.predict([[0,0,1,1,0,0,0,0,2,0,6,0,0,1,1,0,0,0,2,0,5]])):
    print('Poisonous')
else:
    print('Edible')
# Out:
# Edible

# %%
with open("Mushroom_dt.dot", "w") as f:
    decision_tree = tree.export_graphviz(training1, out_file=f)

# %%
# !dot -Tpdf Mushroom_dt.dot -o Mushroom_dt.pdf
